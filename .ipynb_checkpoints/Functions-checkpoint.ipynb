# %% [markdown]
# ## Pandas Functions

# %%
import pandas as pd 

csv_1 = pd.read_csv("/home/pramiz/Desktop/oidv6/path_to_save_directory/metadata/class-descriptions-boxable.csv")
csv_1
# Out:
#        /m/011k07    Tortoise
# 0    /m/011q46kg   Container
# 1      /m/012074      Magpie
# 2      /m/0120dh  Sea turtle
# 3      /m/01226z    Football
# 4      /m/012n7d   Ambulance
# ..           ...         ...
# 595     /m/0qmmr  Wheelchair
# 596   /m/0wdt60w  Rugby ball
# 597      /m/0xfy   Armadillo
# 598     /m/0xzly     Maracas
# 599     /m/0zvk5      Helmet
#
# [600 rows x 2 columns]

# %%
csv_1.index
# Out:
# RangeIndex(start=0, stop=600, step=1)

# %%
csv_1.columns
# Out:
# Index(['/m/011k07', 'Tortoise'], dtype='object')

# %%
csv_1.describe()
# Out:
#        /m/011k07 Tortoise
# count        600      600
# unique       600      600
# top     /m/0zvk5   Helmet
# freq           1        1

# %%
csv_1.head(3)
# Out:
#      /m/011k07    Tortoise
# 0  /m/011q46kg   Container
# 1    /m/012074      Magpie
# 2    /m/0120dh  Sea turtle

# %%
csv_1.tail(2)
# Out:
#     /m/011k07 Tortoise
# 598  /m/0xzly  Maracas
# 599  /m/0zvk5   Helmet

# %%
csv_1[:60]
# Out:
#       /m/011k07                    Tortoise
# 0   /m/011q46kg                   Container
# 1     /m/012074                      Magpie
# 2     /m/0120dh                  Sea turtle
# 3     /m/01226z                    Football
# 4     /m/012n7d                   Ambulance
# 5     /m/012w5l                      Ladder
# 6     /m/012xff                  Toothbrush
# 7     /m/012ysf                     Syringe
# 8     /m/0130jx                        Sink
# 9     /m/0138tl                         Toy
# 10    /m/013y1f  Organ (Musical Instrument)
# 11    /m/01432t               Cassette deck
# 12    /m/014j1m                       Apple
# 13    /m/014sv8                   Human eye
# 14    /m/014trl                   Cosmetics
# 15    /m/014y4n                      Paddle
# 16    /m/0152hh                     Snowman
# 17     /m/01599                        Beer
# 18     /m/01_5g                  Chopsticks
# 19    /m/015h_t                 Human beard
# ...

# %%
print(type(csv_1))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
csv_1.loc[[2,3],["Tortoise"]]
# Out:
#      Tortoise
# 2  Sea turtle
# 3    Football

# %%
csv_1.loc[[2,3],:]
# Out:
#    /m/011k07    Tortoise
# 2  /m/0120dh  Sea turtle
# 3  /m/01226z    Football

# %%
csv_1.iloc[0,1]
# Out:
# 'Container'
